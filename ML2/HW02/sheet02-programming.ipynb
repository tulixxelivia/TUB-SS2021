# %% [markdown]
# # Canonical Correlation Analysis
#
# In this exercise, we consider canonical correlation analysis (CCA) on two simple problems, one in low dimensions and one in high dimensions. The goal is to implement the primal and dual versions of CCA to handle these two different cases. The first dataset consists of two trajectories in two dimensions. The dataset is extracted and plotted below. The first data points are shown in dark blue, and the last ones are shown in yellow.

# %%
import numpy
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import utils

X,Y   = utils.getdata()
p1,p2 = utils.plotdata(X,Y)

# %% [markdown]
# For these two trajetories, that can be understood as two different modalities of the same data, we would like determine under which projections they appear maximally correlated.
#
# ### Implementing Primal CCA
#
# As stated in the lecture, the CCA problem in its primal form consists of maximizing the cross-correlation objective:
#
# $$J(w_x,w_y) =  w_x^\top C_{xy} w_y$$
#
# subject to autcorrelation constraints $w_x^\top C_{xx} w_x = 1$ and $w_y^\top C_{yy} w_y = 1$. Using the method of Lagrange multipliers, this optimization problem can be reduced to finding the first eigenvector of the generalized eigenvalue problem:
#
# $$
# \begin{bmatrix}0 & C_{xy}\\C_{yx} & 0\end{bmatrix}
# \begin{bmatrix}w_x\\w_y\end{bmatrix} =
# \lambda
# \begin{bmatrix}C_{xx} & 0\\0 & C_{yy}\end{bmatrix}
# \begin{bmatrix}w_x\\w_y\end{bmatrix}
# $$
#
# Your first task is to write a function that solves the CCA problem in the primal (i.e. that solves the generalized eigenvalue problem above). The function you need to implement receives two matrices `X` and `Y` of size `N` $\times$ `d1` and  `N` $\times$ `d2` respectively. It returns two vectors of size `d1` and `d2` corresponding to the projections associated to the modalities `X` and `Y`. *(Hint: Note that the data matrices `X` and `Y` have not been centered yet.)*

# %%
import numpy

def CCAprimal(X,Y):

    ## -------------------------------
    ## My solution
    ## -------------------------------
    # compute auto-covariance
    Cxx = numpy.cov(X,rowvar=False)
    Cyy = numpy.cov(Y,rowvar=False)
    # compute cross-covariance
    centerX = X - numpy.mean(X,axis = 0,keepdims=True)
    centerY = Y - numpy.mean(Y,axis = 0,keepdims=True)
    Cxy = (centerX.T @ centerY)/(X.shape[0]-1)
    Cyx = (centerY.T @ centerX)/(X.shape[0]-1)
    # compute the right matrix of the equality
    x = Cxx.shape[0] + Cyy.shape[0]
    y = Cxx.shape[1] + Cyy.shape[1]
    Cr = numpy.zeros((x,y))
    Cr[0:Cxx.shape[0],0:Cxx.shape[1]] = Cxx
    Cr[Cxx.shape[0]:,Cxx.shape[1]:] = Cyy
    # compute the left matrix of the equality
    Cl = numpy.zeros((x,y))
    Cl[0:Cxy.shape[0],Cyx.shape[1]:] = Cxy
    Cl[Cxy.shape[0]:,0:Cyx.shape[1]] = Cyx
    C = numpy.linalg.inv(Cr) @ Cl
    # solve the eigenvalue problem and as argmax problem,chose the first eigenvector which corresponds to largest eigenvalue
    w,v = numpy.linalg.eig(C)
    ind = numpy.argmax(w)
    wx = -v[0:Cxx.shape[0],ind]
    wy = -v[Cxx.shape[0]:,ind]
    ## -------------------------------
    
    return wx,wy

# %% [markdown]
# The function can now be called with our dataset. The learned projection vectors $w_x$ and $w_y$ are plotted as red arrows.

# %%
wx,wy = CCAprimal(X,Y)

p1,p2 = utils.plotdata(X,Y)
p1.arrow(0,0,1*wx[0],1*wx[1],color='red',width=0.1)
p2.arrow(0,0,1*wy[0],1*wy[1],color='red',width=0.1)
plt.show()

# %% [markdown]
# In each modality, the arrow points in a specific direction (note that the optimal CCA directions are defined up to a sign flip of both $w_x$ and $w_y$). Furthermore, we can verify CCA has learned a meaningful solution by projecting the data on it.

# %%
plt.figure(figsize=(6,2))
plt.plot(numpy.dot(X,wx))
plt.plot(numpy.dot(Y,wy))
plt.show()

# %% [markdown]
# Clearly, the data is correlated in the projected space.
#
# ### Implementing Dual CCA
#
# In the second part of the exercise, we consider the case where the data is high dimensional (with `d` $\gg$ `N`). Such high-dimensionality occurs for example, when input data are images. We consider the scenario where sources emit spatially, and two (noisy) receivers measure the spatial field at different locations. We would like to identify signal that is common to the two measured locations, e.g. a given source emitting at a given frequency. We first load the data and show one example.

# %%
X,Y = utils.getHDdata()

utils.plotHDdata(X[0],Y[0])
plt.show()

# %% [markdown]
# Several sources can be perceived, however, there is a significant level of noise. Here again, we will use CCA to find subspaces where the two modalities are maximally correlated. In this example, because there are many more dimensions than there are data points, it is more advantageous to solve CCA in the dual. Your task is to implement a CCA dual solver that receives two data matrices of size `N` $\times$ `d1` and `N` $\times$ `d2` respectively as input, and returns the associate CCA directions (two vectors of respective sizes `d1` and `d2`).

# %%
def CCAdual(X,Y):

    ## -------------------------------
    ## My solution
    ## -------------------------------
    # center the data
    X = X - X.mean(axis = 0)
    Y = Y - Y.mean(axis = 0)
    # compute the kernel
    Kx,Ky = X @ X.T,Y @ Y.T
    Kxx = Kx @ Kx
    Kyy = Ky @ Ky
    Kxy = Kx @ Ky
    Kyx = Ky @ Kx
    # compute the right matrix of the equality
    x = Kxx.shape[0] + Kyy.shape[0]
    y = Kxx.shape[1] + Kyy.shape[1]
    Cr = numpy.zeros((x,y))
    Cr[0:Kxx.shape[0],0:Kxx.shape[1]] = Kxx
    Cr[Kxx.shape[0]:,Kxx.shape[1]:] = Kyy
    # compute the left matrix of the equality
    Cl = numpy.zeros((x,y))
    Cl[0:Kxy.shape[0],Kyx.shape[1]:] = Kxy
    Cl[Kxy.shape[0]:,0:Kyx.shape[1]] = Kyx
    C = numpy.linalg.inv(Cr) @ Cl
    # eig() and eigh() function give wrong output due to precision overflow so using SVD and power interation 
    # to find the largest Eigenvalue/Eigenvector of C,more stable.
    w = numpy.random.mtrand.RandomState(1234).normal(0,1,(x,1))
    w = w/(w**2).sum()**.5
    
    Jold = -float('inf')
    for it in range(501):
        Cw = C @ w
        w = Cw/(Cw**2).sum()**.5
        J = w.T @ Cw
        if numpy.absolute(J - Jold) < 0.0003:
            print(J - Jold)
            break
        Jold = J
        print('iteration %2d J = %10.3f'%(it,J))
    ax = w[0:Kxx.shape[0]]
    ay = w[Kxx.shape[0]:]
    wx = X.T @ ax
    wy = X.T @ ay
    print(w[0])
    ## -------------------------------
    
    return wx,wy

# %% [markdown]
# We now call the function we have implemented with a training sequence of 100 pairs of images. Because the returned solution is of same dimensions as the inputs, it can be rendered in a similar fashion.

# %%
wx,wy = CCAdual(X[:100],Y[:100])

utils.plotHDdata(wx,wy)
plt.show()
# Out:
# iteration  0 J =      2.703
# iteration  1 J =      1.267
# iteration  2 J =      1.060
# iteration  3 J =      1.369
# iteration  4 J =      1.580
# iteration  5 J =      1.038
# iteration  6 J =      2.988
# iteration  7 J =      0.874
# iteration  8 J =      2.411
# iteration  9 J =      1.203
# iteration 10 J =      2.156
# iteration 11 J =      1.116
# iteration 12 J =      2.071
# iteration 13 J =      1.300
# iteration 14 J =      1.788
# iteration 15 J =      1.379
# iteration 16 J =      1.688
# iteration 17 J =      1.455
# iteration 18 J =      1.548
# iteration 19 J =      1.568
# iteration 20 J =      1.440
# iteration 21 J =      1.646
# iteration 22 J =      1.360
# iteration 23 J =      1.741
# iteration 24 J =      1.293
# iteration 25 J =      1.816
# iteration 26 J =      1.259
# iteration 27 J =      1.862
# iteration 28 J =      1.251
# iteration 29 J =      1.874
# iteration 30 J =      1.270
# iteration 31 J =      1.842
# iteration 32 J =      1.310
# iteration 33 J =      1.781
# iteration 34 J =      1.364
# iteration 35 J =      1.703
# iteration 36 J =      1.427
# iteration 37 J =      1.620
# iteration 38 J =      1.494
# iteration 39 J =      1.540
# iteration 40 J =      1.561
# iteration 41 J =      1.466
# iteration 42 J =      1.629
# iteration 43 J =      1.402
# iteration 44 J =      1.693
# iteration 45 J =      1.349
# iteration 46 J =      1.753
# iteration 47 J =      1.308
# iteration 48 J =      1.802
# iteration 49 J =      1.281
# iteration 50 J =      1.838
# iteration 51 J =      1.268
# iteration 52 J =      1.856
# iteration 53 J =      1.269
# iteration 54 J =      1.855
# iteration 55 J =      1.281
# iteration 56 J =      1.837
# iteration 57 J =      1.303
# iteration 58 J =      1.804
# iteration 59 J =      1.331
# iteration 60 J =      1.763
# iteration 61 J =      1.364
# iteration 62 J =      1.719
# iteration 63 J =      1.399
# iteration 64 J =      1.674
# iteration 65 J =      1.433
# iteration 66 J =      1.632
# iteration 67 J =      1.466
# iteration 68 J =      1.597
# iteration 69 J =      1.495
# iteration 70 J =      1.569
# iteration 71 J =      1.518
# iteration 72 J =      1.550
# iteration 73 J =      1.532
# iteration 74 J =      1.540
# iteration 75 J =      1.538
# iteration 76 J =      1.539
# iteration 77 J =      1.536
# iteration 78 J =      1.545
# iteration 79 J =      1.526
# iteration 80 J =      1.558
# iteration 81 J =      1.510
# iteration 82 J =      1.576
# iteration 83 J =      1.490
# iteration 84 J =      1.597
# iteration 85 J =      1.468
# iteration 86 J =      1.619
# iteration 87 J =      1.447
# iteration 88 J =      1.640
# iteration 89 J =      1.427
# iteration 90 J =      1.660
# iteration 91 J =      1.410
# iteration 92 J =      1.678
# iteration 93 J =      1.397
# iteration 94 J =      1.691
# iteration 95 J =      1.388
# iteration 96 J =      1.700
# iteration 97 J =      1.384
# iteration 98 J =      1.704
# iteration 99 J =      1.383
# iteration 100 J =      1.704
# iteration 101 J =      1.386
# iteration 102 J =      1.699
# iteration 103 J =      1.393
# iteration 104 J =      1.691
# iteration 105 J =      1.402
# iteration 106 J =      1.680
# iteration 107 J =      1.412
# iteration 108 J =      1.668
# iteration 109 J =      1.423
# iteration 110 J =      1.656
# iteration 111 J =      1.434
# iteration 112 J =      1.644
# iteration 113 J =      1.444
# iteration 114 J =      1.633
# iteration 115 J =      1.452
# iteration 116 J =      1.625
# iteration 117 J =      1.459
# iteration 118 J =      1.619
# iteration 119 J =      1.463
# iteration 120 J =      1.615
# iteration 121 J =      1.465
# iteration 122 J =      1.614
# iteration 123 J =      1.465
# iteration 124 J =      1.616
# iteration 125 J =      1.462
# iteration 126 J =      1.619
# iteration 127 J =      1.458
# iteration 128 J =      1.624
# iteration 129 J =      1.453
# iteration 130 J =      1.630
# iteration 131 J =      1.447
# iteration 132 J =      1.636
# iteration 133 J =      1.441
# iteration 134 J =      1.643
# iteration 135 J =      1.435
# iteration 136 J =      1.648
# iteration 137 J =      1.430
# iteration 138 J =      1.654
# iteration 139 J =      1.426
# iteration 140 J =      1.658
# iteration 141 J =      1.423
# iteration 142 J =      1.660
# iteration 143 J =      1.421
# iteration 144 J =      1.662
# iteration 145 J =      1.421
# iteration 146 J =      1.662
# iteration 147 J =      1.422
# iteration 148 J =      1.661
# iteration 149 J =      1.423
# iteration 150 J =      1.658
# iteration 151 J =      1.426
# iteration 152 J =      1.656
# iteration 153 J =      1.429
# iteration 154 J =      1.652
# iteration 155 J =      1.432
# iteration 156 J =      1.649
# iteration 157 J =      1.435
# iteration 158 J =      1.645
# iteration 159 J =      1.438
# iteration 160 J =      1.642
# iteration 161 J =      1.440
# iteration 162 J =      1.640
# iteration 163 J =      1.442
# iteration 164 J =      1.638
# iteration 165 J =      1.444
# iteration 166 J =      1.637
# iteration 167 J =      1.444
# iteration 168 J =      1.636
# iteration 169 J =      1.444
# iteration 170 J =      1.637
# iteration 171 J =      1.444
# iteration 172 J =      1.637
# iteration 173 J =      1.443
# iteration 174 J =      1.639
# iteration 175 J =      1.441
# iteration 176 J =      1.640
# iteration 177 J =      1.439
# iteration 178 J =      1.642
# iteration 179 J =      1.438
# iteration 180 J =      1.644
# iteration 181 J =      1.436
# iteration 182 J =      1.646
# iteration 183 J =      1.435
# iteration 184 J =      1.647
# iteration 185 J =      1.433
# iteration 186 J =      1.649
# iteration 187 J =      1.433
# iteration 188 J =      1.649
# iteration 189 J =      1.432
# iteration 190 J =      1.650
# iteration 191 J =      1.432
# iteration 192 J =      1.650
# iteration 193 J =      1.432
# iteration 194 J =      1.650
# iteration 195 J =      1.432
# iteration 196 J =      1.649
# iteration 197 J =      1.433
# iteration 198 J =      1.648
# iteration 199 J =      1.434
# iteration 200 J =      1.647
# iteration 201 J =      1.435
# iteration 202 J =      1.646
# iteration 203 J =      1.436
# iteration 204 J =      1.645
# iteration 205 J =      1.436
# iteration 206 J =      1.645
# iteration 207 J =      1.437
# iteration 208 J =      1.644
# iteration 209 J =      1.438
# iteration 210 J =      1.643
# iteration 211 J =      1.438
# iteration 212 J =      1.643
# iteration 213 J =      1.438
# iteration 214 J =      1.643
# iteration 215 J =      1.438
# iteration 216 J =      1.643
# iteration 217 J =      1.438
# iteration 218 J =      1.643
# iteration 219 J =      1.438
# iteration 220 J =      1.643
# iteration 221 J =      1.438
# iteration 222 J =      1.644
# iteration 223 J =      1.437
# iteration 224 J =      1.644
# iteration 225 J =      1.437
# iteration 226 J =      1.645
# iteration 227 J =      1.436
# iteration 228 J =      1.645
# iteration 229 J =      1.436
# iteration 230 J =      1.646
# iteration 231 J =      1.435
# iteration 232 J =      1.646
# iteration 233 J =      1.435
# iteration 234 J =      1.646
# iteration 235 J =      1.435
# iteration 236 J =      1.646
# iteration 237 J =      1.435
# iteration 238 J =      1.647
# iteration 239 J =      1.435
# iteration 240 J =      1.646
# iteration 241 J =      1.435
# iteration 242 J =      1.646
# iteration 243 J =      1.435
# iteration 244 J =      1.646
# iteration 245 J =      1.435
# iteration 246 J =      1.646
# iteration 247 J =      1.436
# iteration 248 J =      1.646
# iteration 249 J =      1.436
# iteration 250 J =      1.645
# iteration 251 J =      1.436
# iteration 252 J =      1.645
# iteration 253 J =      1.436
# iteration 254 J =      1.645
# iteration 255 J =      1.437
# iteration 256 J =      1.645
# iteration 257 J =      1.437
# iteration 258 J =      1.645
# iteration 259 J =      1.437
# iteration 260 J =      1.645
# iteration 261 J =      1.437
# iteration 262 J =      1.645
# iteration 263 J =      1.437
# iteration 264 J =      1.645
# iteration 265 J =      1.437
# iteration 266 J =      1.645
# iteration 267 J =      1.437
# iteration 268 J =      1.645
# iteration 269 J =      1.436
# iteration 270 J =      1.645
# iteration 271 J =      1.436
# iteration 272 J =      1.645
# iteration 273 J =      1.436
# iteration 274 J =      1.645
# iteration 275 J =      1.436
# iteration 276 J =      1.645
# iteration 277 J =      1.436
# iteration 278 J =      1.645
# iteration 279 J =      1.436
# iteration 280 J =      1.646
# iteration 281 J =      1.436
# iteration 282 J =      1.646
# iteration 283 J =      1.436
# iteration 284 J =      1.646
# iteration 285 J =      1.436
# iteration 286 J =      1.646
# iteration 287 J =      1.436
# iteration 288 J =      1.646
# iteration 289 J =      1.436
# iteration 290 J =      1.645
# iteration 291 J =      1.436
# iteration 292 J =      1.645
# iteration 293 J =      1.436
# iteration 294 J =      1.645
# iteration 295 J =      1.436
# iteration 296 J =      1.645
# iteration 297 J =      1.436
# iteration 298 J =      1.645
# iteration 299 J =      1.436
# iteration 300 J =      1.645
# iteration 301 J =      1.436
# iteration 302 J =      1.645
# iteration 303 J =      1.436
# iteration 304 J =      1.645
# iteration 305 J =      1.436
# iteration 306 J =      1.645
# iteration 307 J =      1.436
# iteration 308 J =      1.645
# iteration 309 J =      1.436
# iteration 310 J =      1.645
# iteration 311 J =      1.436
# iteration 312 J =      1.645
# iteration 313 J =      1.436
# iteration 314 J =      1.645
# iteration 315 J =      1.436
# iteration 316 J =      1.645
# iteration 317 J =      1.436
# iteration 318 J =      1.645
# iteration 319 J =      1.436
# iteration 320 J =      1.645
# iteration 321 J =      1.436
# iteration 322 J =      1.645
# iteration 323 J =      1.436
# iteration 324 J =      1.645
# iteration 325 J =      1.436
# iteration 326 J =      1.645
# iteration 327 J =      1.436
# iteration 328 J =      1.645
# iteration 329 J =      1.436
# iteration 330 J =      1.645
# iteration 331 J =      1.436
# iteration 332 J =      1.645
# iteration 333 J =      1.436
# iteration 334 J =      1.645
# iteration 335 J =      1.436
# iteration 336 J =      1.645
# iteration 337 J =      1.436
# iteration 338 J =      1.645
# iteration 339 J =      1.436
# iteration 340 J =      1.645
# iteration 341 J =      1.436
# iteration 342 J =      1.645
# iteration 343 J =      1.436
# iteration 344 J =      1.645
# iteration 345 J =      1.436
# iteration 346 J =      1.645
# iteration 347 J =      1.436
# iteration 348 J =      1.645
# iteration 349 J =      1.436
# iteration 350 J =      1.645
# iteration 351 J =      1.436
# iteration 352 J =      1.645
# iteration 353 J =      1.436
# iteration 354 J =      1.645
# iteration 355 J =      1.436
# iteration 356 J =      1.645
# iteration 357 J =      1.436
# iteration 358 J =      1.645
# iteration 359 J =      1.436
# iteration 360 J =      1.645
# iteration 361 J =      1.436
# iteration 362 J =      1.645
# iteration 363 J =      1.436
# iteration 364 J =      1.645
# iteration 365 J =      1.436
# iteration 366 J =      1.645
# iteration 367 J =      1.436
# iteration 368 J =      1.645
# iteration 369 J =      1.436
# iteration 370 J =      1.645
# iteration 371 J =      1.436
# iteration 372 J =      1.645
# iteration 373 J =      1.436
# iteration 374 J =      1.645
# iteration 375 J =      1.436
# iteration 376 J =      1.645
# iteration 377 J =      1.436
# iteration 378 J =      1.645
# iteration 379 J =      1.436
# iteration 380 J =      1.645
# iteration 381 J =      1.436
# iteration 382 J =      1.645
# iteration 383 J =      1.436
# iteration 384 J =      1.645
# iteration 385 J =      1.436
# iteration 386 J =      1.645
# iteration 387 J =      1.436
# iteration 388 J =      1.645
# iteration 389 J =      1.436
# iteration 390 J =      1.645
# iteration 391 J =      1.436
# iteration 392 J =      1.645
# iteration 393 J =      1.436
# iteration 394 J =      1.645
# iteration 395 J =      1.436
# iteration 396 J =      1.645
# iteration 397 J =      1.436
# iteration 398 J =      1.645
# iteration 399 J =      1.436
# iteration 400 J =      1.645
# iteration 401 J =      1.436
# iteration 402 J =      1.645
# iteration 403 J =      1.436
# iteration 404 J =      1.645
# iteration 405 J =      1.436
# iteration 406 J =      1.645
# iteration 407 J =      1.436
# iteration 408 J =      1.645
# iteration 409 J =      1.436
# iteration 410 J =      1.645
# iteration 411 J =      1.436
# iteration 412 J =      1.645
# iteration 413 J =      1.436
# iteration 414 J =      1.645
# iteration 415 J =      1.436
# iteration 416 J =      1.645
# iteration 417 J =      1.436
# iteration 418 J =      1.645
# iteration 419 J =      1.436
# iteration 420 J =      1.645
# iteration 421 J =      1.436
# iteration 422 J =      1.645
# iteration 423 J =      1.436
# iteration 424 J =      1.645
# iteration 425 J =      1.436
# iteration 426 J =      1.645
# iteration 427 J =      1.436
# iteration 428 J =      1.645
# iteration 429 J =      1.436
# iteration 430 J =      1.645
# iteration 431 J =      1.436
# iteration 432 J =      1.645
# iteration 433 J =      1.436
# iteration 434 J =      1.645
# iteration 435 J =      1.436
# iteration 436 J =      1.645
# iteration 437 J =      1.436
# iteration 438 J =      1.645
# iteration 439 J =      1.436
# iteration 440 J =      1.645
# iteration 441 J =      1.436
# iteration 442 J =      1.645
# iteration 443 J =      1.436
# iteration 444 J =      1.645
# iteration 445 J =      1.436
# iteration 446 J =      1.645
# iteration 447 J =      1.436
# iteration 448 J =      1.645
# iteration 449 J =      1.436
# iteration 450 J =      1.645
# iteration 451 J =      1.436
# iteration 452 J =      1.645
# iteration 453 J =      1.436
# iteration 454 J =      1.645
# iteration 455 J =      1.436
# iteration 456 J =      1.645
# iteration 457 J =      1.436
# iteration 458 J =      1.645
# iteration 459 J =      1.436
# iteration 460 J =      1.645
# iteration 461 J =      1.436
# iteration 462 J =      1.645
# iteration 463 J =      1.436
# iteration 464 J =      1.645
# iteration 465 J =      1.436
# iteration 466 J =      1.645
# iteration 467 J =      1.436
# iteration 468 J =      1.645
# iteration 469 J =      1.436
# iteration 470 J =      1.645
# iteration 471 J =      1.436
# iteration 472 J =      1.645
# iteration 473 J =      1.436
# iteration 474 J =      1.645
# iteration 475 J =      1.436
# iteration 476 J =      1.645
# iteration 477 J =      1.436
# iteration 478 J =      1.645
# iteration 479 J =      1.436
# iteration 480 J =      1.645
# iteration 481 J =      1.436
# iteration 482 J =      1.645
# iteration 483 J =      1.436
# iteration 484 J =      1.645
# iteration 485 J =      1.436
# iteration 486 J =      1.645
# iteration 487 J =      1.436
# iteration 488 J =      1.645
# iteration 489 J =      1.436
# iteration 490 J =      1.645
# iteration 491 J =      1.436
# iteration 492 J =      1.645
# iteration 493 J =      1.436
# iteration 494 J =      1.645
# iteration 495 J =      1.436
# iteration 496 J =      1.645
# iteration 497 J =      1.436
# iteration 498 J =      1.645
# iteration 499 J =      1.436
# iteration 500 J =      1.645
# [0.02141314]

# %% [markdown]
# Here, we can clearly see a common factor that has been extracted between the two fields, specifically a point source emitting at a particular frequency. A test sequence of 100 pairs of images can now be projected on these two filters:

# %%
plt.figure(figsize=(6,2))
plt.plot(numpy.dot(X[100:],wx))
plt.plot(numpy.dot(Y[100:],wy))
plt.show()

# %% [markdown]
# Clearly the two projected signals are correlated and the input noise has been strongly reduced.
